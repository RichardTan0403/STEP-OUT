# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('Cleaned-data_1.3.csv')
dataset.head()
# Out:
#         Gender Severity Level  Age 60+  Diarrhea  Difficulty-in-Breathing  \
# 0  Transgender         Severe        1         0                        1
# 1  Transgender         Severe        1         0                        1
# 2  Transgender         Severe        1         0                        1
# 3  Transgender         Severe        1         0                        1
# 4  Transgender         Severe        1         0                        1
#
#    Dry-Cough  Fever  Nasal-Congestion  Pains  Runny-Nose  Sore-Throat  \
# 0          1      0                 1      0           0            0
# 1          1      0                 1      0           0            0
# 2          1      0                 1      0           0            0
# 3          1      0                 1      0           1            0
# 4          1      0                 1      0           1            0
#
#    Tiredness  Outlying Status
# 0          1                1
# 1          1                1
# 2          1                1
# 3          1                1
# 4          1                1

# %%
dataset.columns
# Out:
# Index(['Gender', 'Severity Level', 'Age 60+', 'Diarrhea',
#        'Difficulty-in-Breathing', 'Dry-Cough', 'Fever', 'Nasal-Congestion',
#        'Pains', 'Runny-Nose', 'Sore-Throat', 'Tiredness', 'Outlying Status'],
#       dtype='object')

# %%
dataset['Gender'].replace(['Male','Female','Transgender'], [0,1,2], inplace = True)
dataset['Severity Level'].replace(['None','Mild','Moderate','Severe'], [0,1,2,3], inplace = True)

# %%
dataset.head()
# Out:
#    Gender  Severity Level  Age 60+  Diarrhea  Difficulty-in-Breathing  \
# 0       2               3        1         0                        1
# 1       2               3        1         0                        1
# 2       2               3        1         0                        1
# 3       2               3        1         0                        1
# 4       2               3        1         0                        1
#
#    Dry-Cough  Fever  Nasal-Congestion  Pains  Runny-Nose  Sore-Throat  \
# 0          1      0                 1      0           0            0
# 1          1      0                 1      0           0            0
# 2          1      0                 1      0           0            0
# 3          1      0                 1      0           1            0
# 4          1      0                 1      0           1            0
#
#    Tiredness  Outlying Status
# 0          1                1
# 1          1                1
# 2          1                1
# 3          1                1
# 4          1                1

# %%
dataset['Outlying Status'].value_counts()
# Out:
# 0    171990
# 1    144810
# Name: Outlying Status, dtype: int64

# %%
dataset_corr = dataset
sns.set(rc={'figure.figsize':(15,15)})
sns.heatmap(dataset_corr.corr(), vmax=1, square=True, annot=True)
plt.show()

# %%
Y = dataset.iloc[:,-1].values
X = dataset.drop(['Gender','Outlying Status'],axis = 1)

# %%
X
# Out:
#         Severity Level  Age 60+  Diarrhea  Difficulty-in-Breathing  Dry-Cough  \
# 0                    3        1         0                        1          1
# 1                    3        1         0                        1          1
# 2                    3        1         0                        1          1
# 3                    3        1         0                        1          1
# 4                    3        1         0                        1          1
# ...                ...      ...       ...                      ...        ...
# 316795               1        0         0                        1          1
# 316796               1        0         0                        1          1
# 316797               1        0         0                        1          1
# 316798               1        0         0                        1          1
# 316799               1        0         0                        1          1
#
#         Fever  Nasal-Congestion  Pains  Runny-Nose  Sore-Throat  Tiredness
# 0           0                 1      0           0            0          1
# 1           0                 1      0           0            0          1
# 2           0                 1      0           0            0          1
# 3           0                 1      0           1            0          1
# 4           0                 1      0           1            0          1
# ...       ...               ...    ...         ...          ...        ...
# 316795      0                 1      0           1            1          0
# 316796      0                 1      0           1            1          0
# 316797      0                 1      0           1            1          0
# 316798      0                 1      0           1            1          0
# 316799      0                 1      0           1            1          0
#
# [316800 rows x 11 columns]

# %%
#Splitting dataset into training and testing dataset
from sklearn.model_selection import train_test_split as tts
Trained_X,Tested_X,Trained_Y,Tested_Y = tts(X,Y,test_size=0.2,random_state=5)

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.metrics import accuracy_score
rfc = RFC()
rfc.fit(Trained_X, Trained_Y)

y_pred4 = rfc.predict(Tested_X)
acc = accuracy_score(Tested_Y, y_pred4)
print('Accuracy of Random Forest: ', acc*100, '%')
# Out:
# Accuracy of Random Forest:  100.0 %

# %%
Trained_X
# Out:
#         Severity Level  Age 60+  Diarrhea  Difficulty-in-Breathing  Dry-Cough  \
# 266350               0        0         1                        0          1
# 235541               0        0         0                        1          1
# 194898               3        1         0                        1          0
# 179922               0        0         0                        0          1
# 188629               1        0         0                        1          1
# ...                ...      ...       ...                      ...        ...
# 232422               0        0         1                        1          1
# 124605               3        0         0                        0          0
# 20463                0        0         0                        0          0
# 18638                2        0         1                        0          1
# 297827               1        0         0                        1          1
#
#         Fever  Nasal-Congestion  Pains  Runny-Nose  Sore-Throat  Tiredness
# 266350      0                 0      0           1            0          1
# 235541      0                 1      1           0            1          0
# 194898      0                 1      1           1            0          0
# 179922      1                 0      1           0            0          1
# 188629      0                 0      0           1            0          0
# ...       ...               ...    ...         ...          ...        ...
# 232422      0                 0      0           1            1          1
# 124605      1                 1      0           0            0          1
# 20463       0                 0      0           1            0          1
# 18638       0                 0      0           1            0          1
# 297827      0                 1      1           1            0          0
#
# [253440 rows x 11 columns]

# %%
a = [1,1,1,0,1,1,1,1,0,1,1]
a = np.expand_dims(a,0)
result = rfc.predict(a)
result
# Out:
# array([1], dtype=int64)
